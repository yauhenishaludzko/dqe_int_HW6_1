# %%
# %env SPARK_VERSION=3.2.0
# Out:
# env: SPARK_VERSION=3.2.0

# %%
import pydeequ

from pyspark.sql import SparkSession, Row

spark = (SparkSession
    .builder
    .config("spark.jars.packages", pydeequ.deequ_maven_coord)
    .config("spark.jars.excludes", pydeequ.f2j_maven_coord)
    .config("spark.driver.extraClassPath","/home/jovyan/mssql-jdbc-12.6.1.jre11.jar")
    .config("spark.executor.extraClassPath", "/home/jovyan/mssql-jdbc-12.6.1.jre11.jar")
    .getOrCreate())

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://0b111d11022d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
server_name = "jdbc:sqlserver://host.docker.internal;encrypt=true;trustServerCertificate=true"
database_name = "AdventureWorks2012"
url = server_name + ";" + "databaseName=" + database_name + ";"

table = "HumanResources.Employee"
user = "shell84"
password  = "zQ692U3d!"

df = spark.read \
        .format("jdbc") \
        .option("url", url) \
        .option("dbtable", table) \
        .option("user", user) \
        .option("password", password) \
        .load()

df.show()
# Out:
# +----------------+----------------+--------------------+----------------+-----------------+--------------------+----------+-------------+------+----------+------------+-------------+--------------+-----------+--------------------+-------------------+
# |BusinessEntityID|NationalIDNumber|             LoginID|OrganizationNode|OrganizationLevel|            JobTitle| BirthDate|MaritalStatus|Gender|  HireDate|SalariedFlag|VacationHours|SickLeaveHours|CurrentFlag|             rowguid|       ModifiedDate|
# +----------------+----------------+--------------------+----------------+-----------------+--------------------+----------+-------------+------+----------+------------+-------------+--------------+-----------+--------------------+-------------------+
# |               1|       295847284|adventure-works\ken0|            null|             null|Chief Executive O...|1969-01-29|            S|     M|2009-01-14|        true|           99|            69|       true|F01251E5-96A3-448...|2014-06-30 00:00:00|
# |               2|       245797967|adventure-works\t...|            [58]|                1|Vice President of...|1971-08-01|            S|     F|2008-01-31|        true|            1|            20|       true|45E8F437-670D-440...|2014-06-30 00:00:00|
# |               3|       509647174|adventure-works\r...|         [5A C0]|                2| Engineering Manager|1974-11-12|            M|     M|2007-11-11|        true|            2|            21|       true|9BBBFB2C-EFBB-421...|2014-06-30 00:00:00|
# |               4|       112457891|adventure-works\rob0|         [5A D6]|                3|Senior Tool Designer|1974-12-23|            S|     M|2007-12-05|       false|           48|            80|       true|59747955-87B8-443...|2014-06-30 00:00:00|
# |               5|       695256908|adventure-works\g...|         [5A DA]|                3|     Design Engineer|1952-09-27|            M|     F|2008-01-06|        true|            5|            22|       true|EC84AE09-F9B8-4A1...|2014-06-30 00:00:00|
# |               6|       998320692|adventure-works\j...|         [5A DE]|                3|     Design Engineer|1959-03-11|            M|     M|2008-01-24|        true|            6|            23|       true|E39056F1-9CD5-478...|2014-06-30 00:00:00|
# |               7|       134969118|adventure-works\d...|         [5A E1]|                3|Research and Deve...|1987-02-24|            M|     M|2009-02-08|        true|           61|            50|       true|4F46DECA-EF01-41F...|2014-06-30 00:00:00|
# |               8|       811994146|adventure-works\d...|      [5A E1 58]|                4|Research and Deve...|1986-06-05|            S|     F|2008-12-29|        true|           62|            51|       true|31112635-663B-401...|2014-06-30 00:00:00|
# |               9|       658797903|adventure-works\g...|      [5A E1 68]|                4|Research and Deve...|1979-01-21|            M|     F|2009-01-16|        true|           63|            51|       true|50B6CDC6-7570-47E...|2014-06-30 00:00:00|
# |              10|       879342154|adventure-works\m...|      [5A E1 78]|                4|Research and Deve...|1984-11-30|            M|     M|2009-05-03|        true|           16|            64|       true|EAA43680-5571-40C...|2014-06-30 00:00:00|
# |              11|       974026903|adventure-works\o...|         [5A E3]|                3|Senior Tool Designer|1978-01-17|            S|     M|2010-12-05|       false|            7|            23|       true|F68C7C19-FAC1-438...|2014-06-30 00:00:00|
# |              12|       480168528|adventure-works\t...|      [5A E3 58]|                4|       Tool Designer|1959-07-29|            M|     M|2007-12-11|       false|            9|            24|       true|1D955171-E773-4FA...|2014-06-30 00:00:00|
# |              13|       486228782|adventure-works\j...|      [5A E3 68]|                4|       Tool Designer|1989-05-28|            M|     F|2010-12-23|       false|            8|            24|       true|954B91B6-5AA7-48C...|2014-06-30 00:00:00|
# |              14|        42487730|adventure-works\m...|         [5A E5]|                3|Senior Design Eng...|1979-06-16|            S|     M|2010-12-30|        true|            3|            21|       true|46286CA4-46DD-4DD...|2014-06-30 00:00:00|
# |              15|        56920285|adventure-works\s...|         [5A E7]|                3|     Design Engineer|1961-05-02|            M|     F|2011-01-18|        true|            4|            22|       true|54F2FDC0-87C4-406...|2014-06-30 00:00:00|
# |              16|        24756624|adventure-works\d...|            [68]|                1|   Marketing Manager|1975-03-19|            S|     M|2007-12-20|        true|           40|            40|       true|E87029AA-2CBA-4C0...|2014-06-30 00:00:00|
# |              17|       253022876|adventure-works\k...|         [6A C0]|                2| Marketing Assistant|1987-05-03|            S|     M|2007-01-26|       false|           42|            41|       true|1B480240-95C0-410...|2014-06-30 00:00:00|
# |              18|       222969461|adventure-works\j...|         [6B 40]|                2|Marketing Specialist|1978-03-06|            S|     M|2011-02-07|       false|           48|            44|       true|64730415-1F58-4E5...|2014-06-30 00:00:00|
# |              19|        52541318|adventure-works\m...|         [6B C0]|                2| Marketing Assistant|1978-01-29|            S|     F|2011-02-14|       false|           43|            41|       true|1F6DA901-C7F7-48A...|2014-06-30 00:00:00|
# |              20|       323403273|adventure-works\w...|         [6C 20]|                2| Marketing Assistant|1975-03-17|            M|     F|2011-01-07|       false|           41|            40|       true|43CCA446-DA1C-454...|2014-06-30 00:00:00|
# +----------------+----------------+--------------------+----------------+-----------------+--------------------+----------+-------------+------+----------+------------+-------------+--------------+-----------+--------------------+-------------------+
# only showing top 20 rows

# %%
### Data Analyzers section
from pydeequ.analyzers import *

# Define the DataFrame Analyzer
analysis_result = AnalysisRunner(spark) \
    .onData(df) \
    .addAnalyzer(Size()) \
    .addAnalyzer(Completeness("BusinessEntityID")) \
    .addAnalyzer(Completeness("NationalIDNumber")) \
    .addAnalyzer(Completeness("email")) \
    .addAnalyzer(Completeness("LoginID")) \
    .addAnalyzer(Completeness("OrganizationNode")) \
    .addAnalyzer(Completeness("rowguid")) \
    .run()

# Display the analysis results
analysis_result_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysis_result)
analysis_result_df.show()
# Out:
# +-------+----------------+------------+-----------------+
# | entity|        instance|        name|            value|
# +-------+----------------+------------+-----------------+
# | Column|         LoginID|Completeness|              1.0|
# | Column|NationalIDNumber|Completeness|              1.0|
# | Column|OrganizationNode|Completeness|0.996551724137931|
# |Dataset|               *|        Size|            290.0|
# | Column|         rowguid|Completeness|              1.0|
# | Column|BusinessEntityID|Completeness|              1.0|
# +-------+----------------+------------+-----------------+
# /usr/local/spark/python/pyspark/sql/dataframe.py:148: UserWarning: DataFrame constructor is internal. Do not directly use it.
#   warnings.warn("DataFrame constructor is internal. Do not directly use it.")

# %%
### Data profiling section
from pydeequ.profiles import *

# Define the DataFrame ColumnProfiler
result = ColumnProfilerRunner(spark) \
    .onData(df) \
    .run()

for col, profile in result.profiles.items():
    print(profile)
# Out:
# StandardProfiles for column: JobTitle: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 66,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 290
#     },
#     "histogram": [
#         [
#             "Production Technician - WC60",
#             26,
#             0.0896551724137931
#         ],
#         [
#             "Sales Representative",
#             14,
#             0.04827586206896552
#         ],
#         [
#             "Research and Development Manager",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Research and Development Engineer",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Quality Assurance Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Production Supervisor - WC60",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Chief Executive Officer",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Human Resources Administrative Assistant",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Production Supervisor - WC45",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Vice President of Engineering",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Production Technician - WC10",
#             17,
#             0.05862068965517241
#         ],
#         [
#             "European Sales Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Chief Financial Officer",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Janitor",
#             4,
#             0.013793103448275862
#         ],
#         [
#             "Master Scheduler",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Marketing Assistant",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Accounts Payable Specialist",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Scheduling Assistant",
#             4,
#             0.013793103448275862
#         ],
#         [
#             "Shipping and Receiving Supervisor",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Production Supervisor - WC50",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Document Control Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Finance Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Design Engineer",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Accounts Receivable Specialist",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Vice President of Sales",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Facilities Administrative Assistant",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Engineering Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Production Supervisor - WC40",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "North American Sales Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Purchasing Assistant",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Accounts Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Production Supervisor - WC10",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Control Specialist",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Marketing Specialist",
#             5,
#             0.017241379310344827
#         ],
#         [
#             "Facilities Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Tool Designer",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Production Technician - WC30",
#             25,
#             0.08620689655172414
#         ],
#         [
#             "Accountant",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Assistant to the Chief Financial Officer",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Production Technician - WC20",
#             22,
#             0.07586206896551724
#         ],
#         [
#             "Maintenance Supervisor",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Shipping and Receiving Clerk",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Purchasing Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Buyer",
#             9,
#             0.03103448275862069
#         ],
#         [
#             "Human Resources Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Information Services Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Production Technician - WC45",
#             15,
#             0.05172413793103448
#         ],
#         [
#             "Production Supervisor - WC20",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Application Specialist",
#             4,
#             0.013793103448275862
#         ],
#         [
#             "Recruiter",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Quality Assurance Supervisor",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Pacific Sales Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Stocker",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Senior Design Engineer",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Production Technician - WC50",
#             26,
#             0.0896551724137931
#         ],
#         [
#             "Document Control Assistant",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Network Administrator",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Production Control Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Quality Assurance Technician",
#             4,
#             0.013793103448275862
#         ],
#         [
#             "Production Supervisor - WC30",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "Network Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Production Technician - WC40",
#             26,
#             0.0896551724137931
#         ],
#         [
#             "Benefits Specialist",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Database Administrator",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Senior Tool Designer",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "Marketing Manager",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "Vice President of Production",
#             1,
#             0.0034482758620689655
#         ]
#     ]
# }
# NumericProfiles for column: SickLeaveHours: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 50,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "45",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "34",
#             5,
#             0.017241379310344827
#         ],
#         [
#             "67",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "66",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "51",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "23",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "62",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "40",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "44",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "33",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "22",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "56",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "55",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "26",
#             4,
#             0.013793103448275862
#         ],
#         [
#             "50",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "37",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "68",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "61",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "46",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "24",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "35",
#             5,
#             0.017241379310344827
#         ],
#         [
#             "59",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "48",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "21",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "54",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "43",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "65",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "57",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "32",
#             5,
#             0.017241379310344827
#         ],
#         [
#             "80",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "49",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "36",
#             5,
#             0.017241379310344827
#         ],
#         [
#             "39",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "25",
#             5,
#             0.017241379310344827
#         ],
#         [
#             "60",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "47",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "31",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "69",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "58",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "64",
#             7,
#             0.02413793103448276
#         ],
#         [
#             "53",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "42",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "20",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "27",
#             5,
#             0.017241379310344827
#         ],
#         [
#             "38",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "30",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "29",
#             4,
#             0.013793103448275862
#         ],
#         [
#             "41",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "63",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "52",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "28",
#             4,
#             0.013793103448275862
#         ]
#     ],
#     "kll": "None",
#     "mean": 45.30689655172414,
#     "maximum": 80.0,
#     "minimum": 20.0,
#     "sum": 13139.0,
#     "stdDev": 14.515352895432944,
#     "approxPercentiles": []
# }
# StandardProfiles for column: ModifiedDate: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# StandardProfiles for column: HireDate: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 168,
#     "dataType": "Unknown",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# NumericProfiles for column: OrganizationLevel: {
#     "completeness": 0.996551724137931,
#     "approximateNumDistinctValues": 4,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "4",
#             190,
#             0.6551724137931034
#         ],
#         [
#             "NullValue",
#             1,
#             0.0034482758620689655
#         ],
#         [
#             "1",
#             6,
#             0.020689655172413793
#         ],
#         [
#             "2",
#             27,
#             0.09310344827586207
#         ],
#         [
#             "3",
#             66,
#             0.22758620689655173
#         ]
#     ],
#     "kll": "None",
#     "mean": 3.5224913494809686,
#     "maximum": 4.0,
#     "minimum": 1.0,
#     "sum": 1018.0,
#     "stdDev": 0.7489411354169508,
#     "approxPercentiles": []
# }
# StandardProfiles for column: rowguid: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 286,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 290
#     },
#     "histogram": null
# }
# StandardProfiles for column: SalariedFlag: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "Boolean",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "false",
#             238,
#             0.8206896551724138
#         ],
#         [
#             "true",
#             52,
#             0.1793103448275862
#         ]
#     ]
# }
# NumericProfiles for column: BusinessEntityID: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 286,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 145.5,
#     "maximum": 290.0,
#     "minimum": 1.0,
#     "sum": 42195.0,
#     "stdDev": 83.7152913152669,
#     "approxPercentiles": []
# }
# StandardProfiles for column: BirthDate: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 272,
#     "dataType": "Unknown",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# StandardProfiles for column: CurrentFlag: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 1,
#     "dataType": "Boolean",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "true",
#             290,
#             1.0
#         ]
#     ]
# }
# StandardProfiles for column: OrganizationNode: {
#     "completeness": 0.996551724137931,
#     "approximateNumDistinctValues": 291,
#     "dataType": "Unknown",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# NumericProfiles for column: NationalIDNumber: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 296,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 290,
#         "Unknown": 0,
#         "String": 0
#     },
#     "histogram": null,
#     "kll": "None",
#     "mean": 461643360.86551726,
#     "maximum": 999440576.0,
#     "minimum": 30845.0,
#     "sum": 133876574651.0,
#     "stdDev": 281425539.92662436,
#     "approxPercentiles": []
# }
# StandardProfiles for column: LoginID: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 284,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 290
#     },
#     "histogram": null
# }
# NumericProfiles for column: VacationHours: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 99,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "45",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "98",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "34",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "67",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "93",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "12",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "66",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "89",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "51",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "84",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "8",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "73",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "78",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "19",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "23",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "62",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "4",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "88",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "77",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "40",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "15",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "11",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "90",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "9",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "44",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "33",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "22",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "56",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "55",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "26",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "50",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "37",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "68",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "61",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "13",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "46",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "99",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "24",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "94",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "83",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "35",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "16",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "79",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "5",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "72",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "10",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "59",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "87",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "48",
#             4,
#             0.013793103448275862
#         ],
#         [
#             "21",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "76",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "54",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "43",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "65",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "71",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "57",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "32",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "80",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "82",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "49",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "6",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "36",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "1",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "39",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "17",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "25",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "60",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "14",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "47",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "31",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "96",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "69",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "95",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "58",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "64",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "53",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "42",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "75",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "0",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "20",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "27",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "70",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "2",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "86",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "38",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "81",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "92",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "18",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "30",
#             2,
#             0.006896551724137931
#         ],
#         [
#             "7",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "97",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "29",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "41",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "63",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "3",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "74",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "91",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "52",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "85",
#             3,
#             0.010344827586206896
#         ],
#         [
#             "28",
#             2,
#             0.006896551724137931
#         ]
#     ],
#     "kll": "None",
#     "mean": 50.61379310344827,
#     "maximum": 99.0,
#     "minimum": 0.0,
#     "sum": 14678.0,
#     "stdDev": 28.73654076724508,
#     "approxPercentiles": []
# }
# StandardProfiles for column: Gender: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 290
#     },
#     "histogram": [
#         [
#             "M",
#             206,
#             0.7103448275862069
#         ],
#         [
#             "F",
#             84,
#             0.2896551724137931
#         ]
#     ]
# }
# StandardProfiles for column: MaritalStatus: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 290
#     },
#     "histogram": [
#         [
#             "M",
#             146,
#             0.503448275862069
#         ],
#         [
#             "S",
#             144,
#             0.496551724137931
#         ]
#     ]
# }

# %%
### Constraint Suggestions section
from pydeequ.suggestions import *

# Run constraint suggestion runner on the DataFrame
suggestion_result = ConstraintSuggestionRunner(spark) \
             .onData(df) \
             .addConstraintRule(DEFAULT()) \
             .run()
# Show contraint suggestions
suggestion_result
# Out:
# {'constraint_suggestions': [{'constraint_name': 'CompletenessConstraint(Completeness(JobTitle,None))',
#    'column_name': 'JobTitle',
#    'current_value': 'Completeness: 1.0',
#    'description': "'JobTitle' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("JobTitle")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('SickLeaveHours' has value range '64', '52', '63', '41', '30', '38', '20', '42', '53', '58', '69', '31', '47', '60', '39', '49', '57', '65', '43', '54', '21', '48', '59', '24', '46', '61', '68', '37', '50', '55', '56', '22', '33', '44', '40', '62', '23', '51', '66', '67', '45', '27', '25', '36', '32', '35', '34', '28', '29', '26', '80',`SickLeaveHours` IN ('64', '52', '63', '41', '30', '38', '20', '42', '53', '58', '69', '31', '47', '60', '39', '49', '57', '65', '43', '54', '21', '48', '59', '24', '46', '61', '68', '37', '50', '55', '56', '22', '33', '44', '40', '62', '23', '51', '66', '67', '45', '27', '25', '36', '32', '35', '34', '28', '29', '26', '80'),None))",
#    'column_name': 'SickLeaveHours',
#    'current_value': 'Compliance: 1',
#    'description': "'SickLeaveHours' has value range '64', '52', '63', '41', '30', '38', '20', '42', '53', '58', '69', '31', '47', '60', '39', '49', '57', '65', '43', '54', '21', '48', '59', '24', '46', '61', '68', '37', '50', '55', '56', '22', '33', '44', '40', '62', '23', '51', '66', '67', '45', '27', '25', '36', '32', '35', '34', '28', '29', '26', '80'",
#    'suggesting_rule': 'CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3718/0x00000008020c66e8@25ce0b9b)',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("SickLeaveHours", ["64", "52", "63", "41", "30", "38", "20", "42", "53", "58", "69", "31", "47", "60", "39", "49", "57", "65", "43", "54", "21", "48", "59", "24", "46", "61", "68", "37", "50", "55", "56", "22", "33", "44", "40", "62", "23", "51", "66", "67", "45", "27", "25", "36", "32", "35", "34", "28", "29", "26", "80"])'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(SickLeaveHours,None))',
#    'column_name': 'SickLeaveHours',
#    'current_value': 'Completeness: 1.0',
#    'description': "'SickLeaveHours' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("SickLeaveHours")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('SickLeaveHours' has value range '64', '52', '63', '41', '30', '38', '20', '42', '53', '58', '69', '31', '47', '60', '39', '49', '57', '65', '43', '54', '21', '48', '59', '24', '46', '61', '68', '37', '50', '55', '56', '22', '33', '44', '40', '62', '23', '51', '66', '67', '45', '27', '25', '36' for at least 86.0% of values,`SickLeaveHours` IN ('64', '52', '63', '41', '30', '38', '20', '42', '53', '58', '69', '31', '47', '60', '39', '49', '57', '65', '43', '54', '21', '48', '59', '24', '46', '61', '68', '37', '50', '55', '56', '22', '33', '44', '40', '62', '23', '51', '66', '67', '45', '27', '25', '36'),None))",
#    'column_name': 'SickLeaveHours',
#    'current_value': 'Compliance: 0.9034482758620695',
#    'description': "'SickLeaveHours' has value range '64', '52', '63', '41', '30', '38', '20', '42', '53', '58', '69', '31', '47', '60', '39', '49', '57', '65', '43', '54', '21', '48', '59', '24', '46', '61', '68', '37', '50', '55', '56', '22', '33', '44', '40', '62', '23', '51', '66', '67', '45', '27', '25', '36' for at least 86.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3719/0x00000008020c55c0@52a319ad)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("SickLeaveHours", ["64", "52", "63", "41", "30", "38", "20", "42", "53", "58", "69", "31", "47", "60", "39", "49", "57", "65", "43", "54", "21", "48", "59", "24", "46", "61", "68", "37", "50", "55", "56", "22", "33", "44", "40", "62", "23", "51", "66", "67", "45", "27", "25", "36"], lambda x: x >= 0.86, "It should be above 0.86!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('SickLeaveHours' has no negative values,SickLeaveHours >= 0,None))",
#    'column_name': 'SickLeaveHours',
#    'current_value': 'Minimum: 20.0',
#    'description': "'SickLeaveHours' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("SickLeaveHours")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(ModifiedDate,None))',
#    'column_name': 'ModifiedDate',
#    'current_value': 'Completeness: 1.0',
#    'description': "'ModifiedDate' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("ModifiedDate")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(HireDate,None))',
#    'column_name': 'HireDate',
#    'current_value': 'Completeness: 1.0',
#    'description': "'HireDate' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("HireDate")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('OrganizationLevel' has value range '4', '3', '2' for at least 95.0% of values,`OrganizationLevel` IN ('4', '3', '2'),None))",
#    'column_name': 'OrganizationLevel',
#    'current_value': 'Compliance: 0.9758620689655172',
#    'description': "'OrganizationLevel' has value range '4', '3', '2' for at least 95.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3719/0x00000008020c55c0@52a319ad)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("OrganizationLevel", ["4", "3", "2"], lambda x: x >= 0.95, "It should be above 0.95!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('OrganizationLevel' has no negative values,OrganizationLevel >= 0,None))",
#    'column_name': 'OrganizationLevel',
#    'current_value': 'Minimum: 1.0',
#    'description': "'OrganizationLevel' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("OrganizationLevel")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(OrganizationLevel,None))',
#    'column_name': 'OrganizationLevel',
#    'current_value': 'Completeness: 0.996551724137931',
#    'description': "'OrganizationLevel' has less than 2% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("OrganizationLevel", lambda x: x >= 0.98, "It should be above 0.98!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(rowguid,None))',
#    'column_name': 'rowguid',
#    'current_value': 'Completeness: 1.0',
#    'description': "'rowguid' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("rowguid")'},
#   {'constraint_name': 'UniquenessConstraint(Uniqueness(List(rowguid),None))',
#    'column_name': 'rowguid',
#    'current_value': 'ApproxDistinctness: 0.9862068965517241',
#    'description': "'rowguid' is unique",
#    'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()',
#    'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint',
#    'code_for_constraint': '.isUnique("rowguid")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(SalariedFlag,None))',
#    'column_name': 'SalariedFlag',
#    'current_value': 'Completeness: 1.0',
#    'description': "'SalariedFlag' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("SalariedFlag")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(BusinessEntityID,None))',
#    'column_name': 'BusinessEntityID',
#    'current_value': 'Completeness: 1.0',
#    'description': "'BusinessEntityID' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("BusinessEntityID")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('BusinessEntityID' has no negative values,BusinessEntityID >= 0,None))",
#    'column_name': 'BusinessEntityID',
#    'current_value': 'Minimum: 1.0',
#    'description': "'BusinessEntityID' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("BusinessEntityID")'},
#   {'constraint_name': 'UniquenessConstraint(Uniqueness(List(BusinessEntityID),None))',
#    'column_name': 'BusinessEntityID',
#    'current_value': 'ApproxDistinctness: 0.9862068965517241',
#    'description': "'BusinessEntityID' is unique",
#    'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()',
#    'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint',
#    'code_for_constraint': '.isUnique("BusinessEntityID")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(BirthDate,None))',
#    'column_name': 'BirthDate',
#    'current_value': 'Completeness: 1.0',
#    'description': "'BirthDate' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("BirthDate")'},
#   {'constraint_name': 'UniquenessConstraint(Uniqueness(List(BirthDate),None))',
#    'column_name': 'BirthDate',
#    'current_value': 'ApproxDistinctness: 0.9379310344827586',
#    'description': "'BirthDate' is unique",
#    'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()',
#    'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint',
#    'code_for_constraint': '.isUnique("BirthDate")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(CurrentFlag,None))',
#    'column_name': 'CurrentFlag',
#    'current_value': 'Completeness: 1.0',
#    'description': "'CurrentFlag' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("CurrentFlag")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(OrganizationNode,None))',
#    'column_name': 'OrganizationNode',
#    'current_value': 'Completeness: 0.996551724137931',
#    'description': "'OrganizationNode' has less than 2% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("OrganizationNode", lambda x: x >= 0.98, "It should be above 0.98!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(NationalIDNumber,None))',
#    'column_name': 'NationalIDNumber',
#    'current_value': 'Completeness: 1.0',
#    'description': "'NationalIDNumber' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("NationalIDNumber")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('NationalIDNumber' has no negative values,NationalIDNumber >= 0,None))",
#    'column_name': 'NationalIDNumber',
#    'current_value': 'Minimum: 30845.0',
#    'description': "'NationalIDNumber' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("NationalIDNumber")'},
#   {'constraint_name': 'AnalysisBasedConstraint(DataType(NationalIDNumber,None),<function1>,Some(<function1>),None)',
#    'column_name': 'NationalIDNumber',
#    'current_value': 'DataType: Integral',
#    'description': "'NationalIDNumber' has type Integral",
#    'suggesting_rule': 'RetainTypeRule()',
#    'rule_description': 'If we detect a non-string type, we suggest a type constraint',
#    'code_for_constraint': '.hasDataType("NationalIDNumber", ConstrainableDataTypes.Integral)'},
#   {'constraint_name': 'UniquenessConstraint(Uniqueness(List(NationalIDNumber),None))',
#    'column_name': 'NationalIDNumber',
#    'current_value': 'ApproxDistinctness: 1.0206896551724138',
#    'description': "'NationalIDNumber' is unique",
#    'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()',
#    'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint',
#    'code_for_constraint': '.isUnique("NationalIDNumber")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(LoginID,None))',
#    'column_name': 'LoginID',
#    'current_value': 'Completeness: 1.0',
#    'description': "'LoginID' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("LoginID")'},
#   {'constraint_name': 'UniquenessConstraint(Uniqueness(List(LoginID),None))',
#    'column_name': 'LoginID',
#    'current_value': 'ApproxDistinctness: 0.9793103448275862',
#    'description': "'LoginID' is unique",
#    'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()',
#    'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint',
#    'code_for_constraint': '.isUnique("LoginID")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('VacationHours' has value range '48', '85', '52', '91', '74', '3', '63', '41', '29', '97', '7', '92', '81', '38', '86', '2', '70', '27', '20', '0', '75', '42', '53', '64', '58', '95', '69', '96', '31', '47', '14', '60', '39', '1', '36', '6', '49', '82', '80', '57', '71', '65', '43', '54', '76', '21', '87', '59', '10', '72', '5', '79', '16', '35', '83', '94', '24', '99', '46', '61', '68', '37', '50', '26', '55', '56', '22', '33', '44', '9', '90', '40', '77', '88', '4', '62', '23', '78', '73', '8', '84', '51', '89', '66', '93', '67', '34', '98', '45', '28', '30', '18', '25', '17', '32', '13', '11', '15', '19', '12',`VacationHours` IN ('48', '85', '52', '91', '74', '3', '63', '41', '29', '97', '7', '92', '81', '38', '86', '2', '70', '27', '20', '0', '75', '42', '53', '64', '58', '95', '69', '96', '31', '47', '14', '60', '39', '1', '36', '6', '49', '82', '80', '57', '71', '65', '43', '54', '76', '21', '87', '59', '10', '72', '5', '79', '16', '35', '83', '94', '24', '99', '46', '61', '68', '37', '50', '26', '55', '56', '22', '33', '44', '9', '90', '40', '77', '88', '4', '62', '23', '78', '73', '8', '84', '51', '89', '66', '93', '67', '34', '98', '45', '28', '30', '18', '25', '17', '32', '13', '11', '15', '19', '12'),None))",
#    'column_name': 'VacationHours',
#    'current_value': 'Compliance: 1',
#    'description': "'VacationHours' has value range '48', '85', '52', '91', '74', '3', '63', '41', '29', '97', '7', '92', '81', '38', '86', '2', '70', '27', '20', '0', '75', '42', '53', '64', '58', '95', '69', '96', '31', '47', '14', '60', '39', '1', '36', '6', '49', '82', '80', '57', '71', '65', '43', '54', '76', '21', '87', '59', '10', '72', '5', '79', '16', '35', '83', '94', '24', '99', '46', '61', '68', '37', '50', '26', '55', '56', '22', '33', '44', '9', '90', '40', '77', '88', '4', '62', '23', '78', '73', '8', '84', '51', '89', '66', '93', '67', '34', '98', '45', '28', '30', '18', '25', '17', '32', '13', '11', '15', '19', '12'",
#    'suggesting_rule': 'CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3718/0x00000008020c66e8@25ce0b9b)',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("VacationHours", ["48", "85", "52", "91", "74", "3", "63", "41", "29", "97", "7", "92", "81", "38", "86", "2", "70", "27", "20", "0", "75", "42", "53", "64", "58", "95", "69", "96", "31", "47", "14", "60", "39", "1", "36", "6", "49", "82", "80", "57", "71", "65", "43", "54", "76", "21", "87", "59", "10", "72", "5", "79", "16", "35", "83", "94", "24", "99", "46", "61", "68", "37", "50", "26", "55", "56", "22", "33", "44", "9", "90", "40", "77", "88", "4", "62", "23", "78", "73", "8", "84", "51", "89", "66", "93", "67", "34", "98", "45", "28", "30", "18", "25", "17", "32", "13", "11", "15", "19", "12"])'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(VacationHours,None))',
#    'column_name': 'VacationHours',
#    'current_value': 'Completeness: 1.0',
#    'description': "'VacationHours' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("VacationHours")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('VacationHours' has value range '48', '85', '52', '91', '74', '3', '63', '41', '29', '97', '7', '92', '81', '38', '86', '2', '70', '27', '20', '0', '75', '42', '53', '64', '58', '95', '69', '96', '31', '47', '14', '60', '39', '1', '36', '6', '49', '82', '80', '57', '71', '65', '43', '54', '76', '21', '87', '59', '10', '72', '5', '79', '16', '35', '83', '94', '24', '99', '46', '61', '68', '37', '50', '26', '55', '56', '22', '33', '44', '9', '90', '40', '77', '88', '4', '62', '23', '78', '73', '8', '84', '51', '89', '66', '93', '67', '34' for at least 86.0% of values,`VacationHours` IN ('48', '85', '52', '91', '74', '3', '63', '41', '29', '97', '7', '92', '81', '38', '86', '2', '70', '27', '20', '0', '75', '42', '53', '64', '58', '95', '69', '96', '31', '47', '14', '60', '39', '1', '36', '6', '49', '82', '80', '57', '71', '65', '43', '54', '76', '21', '87', '59', '10', '72', '5', '79', '16', '35', '83', '94', '24', '99', '46', '61', '68', '37', '50', '26', '55', '56', '22', '33', '44', '9', '90', '40', '77', '88', '4', '62', '23', '78', '73', '8', '84', '51', '89', '66', '93', '67', '34'),None))",
#    'column_name': 'VacationHours',
#    'current_value': 'Compliance: 0.9034482758620701',
#    'description': "'VacationHours' has value range '48', '85', '52', '91', '74', '3', '63', '41', '29', '97', '7', '92', '81', '38', '86', '2', '70', '27', '20', '0', '75', '42', '53', '64', '58', '95', '69', '96', '31', '47', '14', '60', '39', '1', '36', '6', '49', '82', '80', '57', '71', '65', '43', '54', '76', '21', '87', '59', '10', '72', '5', '79', '16', '35', '83', '94', '24', '99', '46', '61', '68', '37', '50', '26', '55', '56', '22', '33', '44', '9', '90', '40', '77', '88', '4', '62', '23', '78', '73', '8', '84', '51', '89', '66', '93', '67', '34' for at least 86.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9,com.amazon.deequ.suggestions.rules.FractionalCategoricalRangeRule$$$Lambda$3719/0x00000008020c55c0@52a319ad)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("VacationHours", ["48", "85", "52", "91", "74", "3", "63", "41", "29", "97", "7", "92", "81", "38", "86", "2", "70", "27", "20", "0", "75", "42", "53", "64", "58", "95", "69", "96", "31", "47", "14", "60", "39", "1", "36", "6", "49", "82", "80", "57", "71", "65", "43", "54", "76", "21", "87", "59", "10", "72", "5", "79", "16", "35", "83", "94", "24", "99", "46", "61", "68", "37", "50", "26", "55", "56", "22", "33", "44", "9", "90", "40", "77", "88", "4", "62", "23", "78", "73", "8", "84", "51", "89", "66", "93", "67", "34"], lambda x: x >= 0.86, "It should be above 0.86!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('VacationHours' has no negative values,VacationHours >= 0,None))",
#    'column_name': 'VacationHours',
#    'current_value': 'Minimum: 0.0',
#    'description': "'VacationHours' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("VacationHours")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('Gender' has value range 'M', 'F',`Gender` IN ('M', 'F'),None))",
#    'column_name': 'Gender',
#    'current_value': 'Compliance: 1',
#    'description': "'Gender' has value range 'M', 'F'",
#    'suggesting_rule': 'CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3718/0x00000008020c66e8@25ce0b9b)',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("Gender", ["M", "F"])'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(Gender,None))',
#    'column_name': 'Gender',
#    'current_value': 'Completeness: 1.0',
#    'description': "'Gender' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("Gender")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('MaritalStatus' has value range 'M', 'S',`MaritalStatus` IN ('M', 'S'),None))",
#    'column_name': 'MaritalStatus',
#    'current_value': 'Compliance: 1',
#    'description': "'MaritalStatus' has value range 'M', 'S'",
#    'suggesting_rule': 'CategoricalRangeRule(com.amazon.deequ.suggestions.rules.CategoricalRangeRule$$$Lambda$3718/0x00000008020c66e8@25ce0b9b)',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("MaritalStatus", ["M", "S"])'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(MaritalStatus,None))',
#    'column_name': 'MaritalStatus',
#    'current_value': 'Completeness: 1.0',
#    'description': "'MaritalStatus' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("MaritalStatus")'}]}

# %%
### Constraint Verification section
from pydeequ.checks import *
from pydeequ.verification import *
import pandas as pd

# Define a check for the DataFrame
check = Check(spark, CheckLevel.Warning, "HumanResources.Employee")

# Run verification suite on the DataFrame
checkResult = VerificationSuite(spark) \
    .onData(df) \
    .addCheck(
        check.hasSize(lambda x: x > 1) 
        .isComplete("BusinessEntityID")
        .isComplete("NationalIDNumber")
        .isComplete("LoginID")
        .isComplete("BirthDate")
        .isComplete("HireDate")
        .isComplete("rowguid")
        .isUnique("BusinessEntityID") 
        .isNonNegative("BusinessEntityID")
        .isNonNegative("NationalIDNumber")
        .isUnique("NationalIDNumber")
        .isUnique("LoginID")        
        .isNonNegative("rowguid")        
        .isComplete("JobTitle")
        .isComplete("OrganizationLevel")
    ) \
    .run()

# Print verification run status
print(f"Verification Run Status: {checkResult.status}")

# Convert PySpark DataFrame to Pandas DataFrame
checkResult_df = VerificationResult.checkResultsAsDataFrame(spark, checkResult)
checkResult_df.show()


# Export the DataFrame to test_report.html
constraint_df = checkResult_df.toPandas()
constraint_df.to_html('test_report.html', index=False)
# Out:
# Verification Run Status: Warning
# +--------------------+-----------+------------+--------------------+-----------------+--------------------+
# |               check|check_level|check_status|          constraint|constraint_status|  constraint_message|
# +--------------------+-----------+------------+--------------------+-----------------+--------------------+
# |HumanResources.Em...|    Warning|     Warning|SizeConstraint(Si...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|UniquenessConstra...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|UniquenessConstra...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|UniquenessConstra...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|CompletenessConst...|          Success|                    |
# |HumanResources.Em...|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.99655172...|
# +--------------------+-----------+------------+--------------------+-----------------+--------------------+
# /usr/local/spark/python/pyspark/sql/dataframe.py:148: UserWarning: DataFrame constructor is internal. Do not directly use it.
#   warnings.warn("DataFrame constructor is internal. Do not directly use it.")
